# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("C:/Users/aadhy/Documents/5th Sem/ML/assignment/tested.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df['Age'].replace(np.nan, df['Age'].mean(), inplace=True)
df['Fare'].replace(np.nan, df['Fare'].mean(), inplace=True)
df.drop('Cabin', axis=1,inplace=True)
df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
ax = sns.countplot(x=df['Survived'], palette='RdBu')
ax.bar_label(ax.containers[0])
plt.show()

# %%
cat_var = ['Pclass', 'Sex', 'SibSp', 'Parch', 'Embarked']
num_var = ['Age', 'Fare']

# %%
for column in cat_var:   
    plt.figure(figsize=(12,5))
    plt.subplot(1,2,1)
    ax = sns.countplot(x=column, data=df, palette='Accent')
    ax.bar_label(ax.containers[0])
    plt.show()

# %%
for column in cat_var:
    plt.subplot(1,2,2)
    ax = sns.countplot(x=column, data=df, hue='Survived', palette='Accent')
    ax.bar_label(ax.containers[0])
    ax.bar_label(ax.containers[1])
    plt.show()

# %%
df[num_var].describe()
# Out:
#               Age        Fare
# count  418.000000  418.000000
# mean    30.272590   35.627188
# std     12.634534   55.840500
# min      0.170000    0.000000
# 25%     23.000000    7.895800
# 50%     30.272590   14.454200
# 75%     35.750000   31.500000
# max     76.000000  512.329200

# %%
for column in num_var:
    plt.figure(figsize=(5,3))
    plt.subplot(1,2,1)
    ax = sns.boxplot(df[column])
    plt.show()

# %%
sns.scatterplot(data=df, x='Age', y='Fare', hue='Survived')
plt.show()

# %%
sns.scatterplot(data=df, x='Age', y='Fare', hue='Pclass')
plt.show()

# %%
sns.heatmap(df.corr(), annot=True, cmap='viridis')
plt.title('Correlation')
plt.show()
# Out:
# C:\Users\aadhy\AppData\Local\Temp\ipykernel_20512\1043287141.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), annot=True, cmap='viridis')

# %%
df['Survived'].value_counts().plot(kind='bar')
plt.title('Number of people Survived')
plt.xlabel('sex')
plt.ylabel('survived')
sns.despine()

# %%
plt.scatter(df.SibSp,df.Survived)
plt.title("Survived")
plt.xlabel('Sibsp')
plt.ylabel('Survived')
sns.despine()
plt.show()

# %%
plt.scatter(df.Age,df.Survived)
plt.xlabel('Age')
plt.ylabel('Survived')
plt.title("Age vs Survived")
# Out:
# Text(0.5, 1.0, 'Age vs Survived')
